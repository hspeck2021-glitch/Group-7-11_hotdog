# %%
# The vector cross product is a great computing tool used in simulations for physics to model interactions between
# rotational and linear motion. In three‑dimensional mechanics, many physical forces, like the Magnus effect,
# depend not only on the magnitudes of two vectors but also on their relative orientation. The cross product
# captures this relationship by producing a new vector that is perpendicular to both inputs and whose magnitude reflects how
# strongly the vectors interact. This makes it indispensable when simulating spinning objects moving through the air.
# In numerical simulations, the cross product is implemented using NumPy’s np.cross function, which efficiently computes the
# perpendicular vector from two 3‑component arrays. Correct usage requires attention to vector direction, because reversing the
# order of the inputs reverses the direction of the resulting force.
# In our final project, the cross product was essential for modeling the Magnus force acting on a spinning soccer ball. The
# force depends on the interaction between the ball’s angular velocity vector ω⃗ and its velocity vector v⃗. By computing ω⃗×v⃗, 
# we obtained the correct direction of the lift force, allowing topspin to
# produce downward dip and backspin to generate upward lift. Implementing this in code required extracting the current velocity
# vector at each timestep and applying:

# %%
 f_mag = 0.5 * p * A * r * Cs * np.cross(w, v_current)
