# %% [markdown]
# For all ball flying throught the air.

# %%
import numpy as np
import matplotlib.pyplot as plt

dt = 0.1
t = np.arange(0, 10, dt)
h_array = np.zeros(np.size(t))
v_array = [20]
Cd = 0.47
A = 0.038
p = 1.225
m = 0.42
g = 9.81
angle = 45

h_array[i] = -0.5*g*t[i]**2 + v_array[0]*np.sin(angle)*t[i] + h_initial

i = 1
while h_array[i] >= 0:
    f_drag = 0.5 * (Cd) * p * A *v_array[i-1]*np.sin(angle)**2
    ay = f_drag / m
    v = a * dt
    v_array[i+1] = v_array[i] + Δv
    i =+ 1

plt.plot(t, h_array)

print(h_array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 15
#      12 g = 9.81
#      13 angle = 45
# ---> 15 h_array[i] = -0.5*g*t[i]**2 + v_array[0]*np.sin(angle)*t[i] + h_initial
#      17 i = 1
#      18 while h_array[i] >= 0:
#
# NameError: name 'i' is not defined

# %%
i = 1
while h_array[i] >= 0:
    
    
    f_drag = 0.5 * (Cd) * p * A *v_array[i]**2
    a = f_drag / m
    v = a * dt
    v_array[i+1] = v_array[i] + Δv
    i =+ 1
t=

i=0 
while v_array[i]

def magnus_motion(t, state)
x0,y0 = 0.0, 0.0
theta_rad = np.radians(launch_angle)
vx0 = v0 * np.cos(theta_rad)
vy0 = v0 * np.sin()

w = theta_rad/t

Fd_x = -0.5 * p * Cd * A * v * vx
Fd_y = -0.5 * p * Cd * A * v * vy

Fm_x = 0.5 * rho * Cm * A * v * (-w * vy)
Fm_y = 0.5 * rho * Cm * A * v * (w * vx)

Fx = Fd_x + Fm_x
Fy = -m * g + Fd_y + Fm_y 

Fx_without = Fd_x
Fy_without =  -m * g + Fd_y

plt.figure(figsize=(8,4))
plt.plot(hy_array, dx_array)
plt.xlabel("Distance(m)")
plt.ylabel("Height(m)")
plt.show()
# Out:
#   Cell In[4], line 10
#     t=
#       ^
# SyntaxError: invalid syntax
